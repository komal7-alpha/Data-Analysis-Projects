# %% [markdown]
# ## NOTE:
# - Ensure all required Python libraries are installed before running the script.
# - Required libraries include: requests, pandas, beautifulsoup4.
# - You can install them via pip if needed:
# - pip install requests pandas beautifulsoup4
# - You can run the script as-is if all libraries are installed correctly.
# - Before running, verify the **years** and **countries** for which you want to fetch holiday data.
# - In the code, there is a list called **country_codes = ['australia']**.
# - You can add or remove countries in this list based on your requirements.
# - The year range is controlled by the loop:
# - **for year in range(2024, 2041):**
# - You can adjust the start and end years here.
# - For example, to get holiday data up to 2040, set the range to range(2024, 2041) — note the end year is exclusive, so you add 1 to include 2040.
# - The output CSV files should have a **consistent naming format**, e.g., Holidays_.
# - This consistency helps later when consolidating all files into a single file containing data from all countries.
# - In the workflow, different code cells have different countries listed, but the code structure remains the same.
# - This approach is designed so that scraping runs faster and avoids overloading the server.
# - Ensure you have a stable internet connection during execution as the script fetches live data.
# - The script includes a delay (time.sleep(2)) between requests to be respectful of the website and avoid rate limiting.
# - Before consloidating the file, make sure all excel files are in one folder

# %% [markdown]
# # List of Countries
#
# * Australia
# * Bangladesh
# * Brazil
# * Bulgaria
# * Canada
# * China
# * Czech
# * Denmark
# * Finland
# * France
# * Germany
# * Greece
# * Hong-Kong
# * Hungary
# * India
# * Indonesia
# * Israel
# * Italy
# * Japan
# * Kenya
# * North-Korea
# * South-Korea
# * Malaysia
# * Mongolia
# * Morocco
# * Netherlands
# * Norway
# * Pakistan
# * Philippines
# * Poland
# * Portugal
# * Romania
# * Russia
# * Slovenia
# * South-Africa
# * Spain
# * Sri-Lanka
# * Sweden
# * Taiwan
# * Thailand
# * Turkey
# * Vietnam
# * Ukraine
# * UK
# * New-Zealand
# * Belgium
# * Luxembourg
# * Chile
# * Paraguay
# * Slovakia
# * Ireland
# * Iceland
# * US

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from datetime import datetime
import glob

# %% [markdown]
# 'australia',
# 'bangladesh',
# 'brazil',
# 'bulgaria',
# 'canada'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    # url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}"
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",  # Append year to date
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['australia', 'bangladesh', 'brazil', 'bulgaria', 'canada']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country  # Add country name as a new column
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_1.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))  # Show top 15 rows as preview
# Out:
# Fetching holidays for australia in 2021...
# Fetching holidays for australia in 2022...
# Fetching holidays for australia in 2023...
# Fetching holidays for australia in 2024...
# Fetching holidays for australia in 2025...
# Fetching holidays for australia in 2026...
# Fetching holidays for australia in 2027...
# Fetching holidays for australia in 2028...
# Fetching holidays for australia in 2029...
# Fetching holidays for australia in 2030...
# Fetching holidays for australia in 2031...
# Fetching holidays for australia in 2032...
# Fetching holidays for australia in 2033...
# Fetching holidays for australia in 2034...
# Fetching holidays for australia in 2035...
# Fetching holidays for australia in 2036...
# Fetching holidays for australia in 2037...
# Fetching holidays for australia in 2038...
# Fetching holidays for australia in 2039...
# Fetching holidays for australia in 2040...
# Fetching holidays for bangladesh in 2021...
# Fetching holidays for bangladesh in 2022...
# Fetching holidays for bangladesh in 2023...
# Fetching holidays for bangladesh in 2024...
# Fetching holidays for bangladesh in 2025...
# Fetching holidays for bangladesh in 2026...
# No holiday table found for bangladesh 2026
# Fetching holidays for bangladesh in 2027...
# No holiday table found for bangladesh 2027
# Fetching holidays for bangladesh in 2028...
# No holiday table found for bangladesh 2028
# Fetching holidays for bangladesh in 2029...
# No holiday table found for bangladesh 2029
# Fetching holidays for bangladesh in 2030...
# No holiday table found for bangladesh 2030
# Fetching holidays for bangladesh in 2031...
# No holiday table found for bangladesh 2031
# Fetching holidays for bangladesh in 2032...
# No holiday table found for bangladesh 2032
# Fetching holidays for bangladesh in 2033...
# No holiday table found for bangladesh 2033
# Fetching holidays for bangladesh in 2034...
# No holiday table found for bangladesh 2034
# Fetching holidays for bangladesh in 2035...
# No holiday table found for bangladesh 2035
# Fetching holidays for bangladesh in 2036...
# No holiday table found for bangladesh 2036
# Fetching holidays for bangladesh in 2037...
# No holiday table found for bangladesh 2037
# Fetching holidays for bangladesh in 2038...
# No holiday table found for bangladesh 2038
# Fetching holidays for bangladesh in 2039...
# No holiday table found for bangladesh 2039
# Fetching holidays for bangladesh in 2040...
# No holiday table found for bangladesh 2040
# Fetching holidays for brazil in 2021...
# Fetching holidays for brazil in 2022...
# Fetching holidays for brazil in 2023...
# Fetching holidays for brazil in 2024...
# Fetching holidays for brazil in 2025...
# Fetching holidays for brazil in 2026...
# Fetching holidays for brazil in 2027...
# Fetching holidays for brazil in 2028...
# Fetching holidays for brazil in 2029...
# Fetching holidays for brazil in 2030...
# Fetching holidays for brazil in 2031...
# Fetching holidays for brazil in 2032...
# Fetching holidays for brazil in 2033...
# Fetching holidays for brazil in 2034...
# Fetching holidays for brazil in 2035...
# Fetching holidays for brazil in 2036...
# Fetching holidays for brazil in 2037...
# Fetching holidays for brazil in 2038...
# Fetching holidays for brazil in 2039...
# Fetching holidays for brazil in 2040...
# Fetching holidays for bulgaria in 2021...
# Fetching holidays for bulgaria in 2022...
# Fetching holidays for bulgaria in 2023...
# Fetching holidays for bulgaria in 2024...
# Fetching holidays for bulgaria in 2025...
# Fetching holidays for bulgaria in 2026...
# Fetching holidays for bulgaria in 2027...
# Fetching holidays for bulgaria in 2028...
# Fetching holidays for bulgaria in 2029...
# Fetching holidays for bulgaria in 2030...
# Fetching holidays for bulgaria in 2031...
# Fetching holidays for bulgaria in 2032...
# Fetching holidays for bulgaria in 2033...
# Fetching holidays for bulgaria in 2034...
# Fetching holidays for bulgaria in 2035...
# Fetching holidays for bulgaria in 2036...
# Fetching holidays for bulgaria in 2037...
# Fetching holidays for bulgaria in 2038...
# Fetching holidays for bulgaria in 2039...
# Fetching holidays for bulgaria in 2040...
# Fetching holidays for canada in 2021...
# Fetching holidays for canada in 2022...
# Fetching holidays for canada in 2023...
# Fetching holidays for canada in 2024...
# Fetching holidays for canada in 2025...
# Fetching holidays for canada in 2026...
# Fetching holidays for canada in 2027...
# Fetching holidays for canada in 2028...
# Fetching holidays for canada in 2029...
# Fetching holidays for canada in 2030...
# Fetching holidays for canada in 2031...
# Fetching holidays for canada in 2032...
# Fetching holidays for canada in 2033...
# Fetching holidays for canada in 2034...
# Fetching holidays for canada in 2035...
# Fetching holidays for canada in 2036...
# Fetching holidays for canada in 2037...
# Fetching holidays for canada in 2038...
# Fetching holidays for canada in 2039...
# Fetching holidays for canada in 2040...
#            Date        Day                                     Name  \
# 0    1 Jan 2021     Friday                           New Year's Day
# 1    6 Jan 2021  Wednesday                                 Epiphany
# 2    7 Jan 2021   Thursday                   Orthodox Christmas Day
# 3   14 Jan 2021   Thursday                        Orthodox New Year
# 4   26 Jan 2021    Tuesday                            Australia Day
# 5   28 Jan 2021   Thursday                  Tu B'Shevat (Arbor Day)
# 6    8 Feb 2021     Monday                     Royal Hobart Regatta
# 7   12 Feb 2021     Friday                           Lunar New Year
# 8   12 Feb 2021     Friday                           Lunar New Year
# 9   13 Feb 2021   Saturday           Lunar New Year Holiday (Day 2)
# 10  14 Feb 2021     Sunday                          Valentine's Day
# 11  15 Feb 2021     Monday  Lunar New Year Holiday (Day 2) observed
# 12  16 Feb 2021    Tuesday  Carnival / Shrove Tuesday / Pancake Day
# 13  17 Feb 2021  Wednesday                            Ash Wednesday
# 14  26 Feb 2021     Friday                                    Purim
#
#                 Type    Country
# 0   National Holiday  australia
# 1          Christian  australia
# 2           Orthodox  australia
# 3           Orthodox  australia
# 4   National Holiday  australia
# 5     Jewish holiday  australia
# 6      State Holiday  australia
# 7         Observance  australia
# 8      State Holiday  australia
# 9      State Holiday  australia
# 10        Observance  australia
# 11     State Holiday  australia
# 12         Christian  australia
# 13         Christian  australia
# 14    Jewish holiday  australia

# %% [markdown]
# 'china',
# 'czech',
# 'denmark',
# 'finland',
# 'france'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['china', 'czech', 'denmark', 'finland', 'france']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_2.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for china in 2021...
# Fetching holidays for china in 2022...
# Fetching holidays for china in 2023...
# Fetching holidays for china in 2024...
# Fetching holidays for china in 2025...
# Fetching holidays for china in 2026...
# Fetching holidays for china in 2027...
# Fetching holidays for china in 2028...
# Fetching holidays for china in 2029...
# Fetching holidays for china in 2030...
# Fetching holidays for china in 2031...
# Fetching holidays for china in 2032...
# Fetching holidays for china in 2033...
# Fetching holidays for china in 2034...
# Fetching holidays for china in 2035...
# Fetching holidays for china in 2036...
# Fetching holidays for china in 2037...
# Fetching holidays for china in 2038...
# Fetching holidays for china in 2039...
# Fetching holidays for china in 2040...
# Fetching holidays for czech in 2021...
# Fetching holidays for czech in 2022...
# Fetching holidays for czech in 2023...
# Fetching holidays for czech in 2024...
# Fetching holidays for czech in 2025...
# Fetching holidays for czech in 2026...
# Fetching holidays for czech in 2027...
# Fetching holidays for czech in 2028...
# Fetching holidays for czech in 2029...
# Fetching holidays for czech in 2030...
# Fetching holidays for czech in 2031...
# Fetching holidays for czech in 2032...
# Fetching holidays for czech in 2033...
# Fetching holidays for czech in 2034...
# Fetching holidays for czech in 2035...
# Fetching holidays for czech in 2036...
# Fetching holidays for czech in 2037...
# Fetching holidays for czech in 2038...
# Fetching holidays for czech in 2039...
# Fetching holidays for czech in 2040...
# Fetching holidays for denmark in 2021...
# Fetching holidays for denmark in 2022...
# Fetching holidays for denmark in 2023...
# Fetching holidays for denmark in 2024...
# Fetching holidays for denmark in 2025...
# Fetching holidays for denmark in 2026...
# Fetching holidays for denmark in 2027...
# Fetching holidays for denmark in 2028...
# Fetching holidays for denmark in 2029...
# Fetching holidays for denmark in 2030...
# Fetching holidays for denmark in 2031...
# Fetching holidays for denmark in 2032...
# Fetching holidays for denmark in 2033...
# Fetching holidays for denmark in 2034...
# Fetching holidays for denmark in 2035...
# Fetching holidays for denmark in 2036...
# Fetching holidays for denmark in 2037...
# Fetching holidays for denmark in 2038...
# Fetching holidays for denmark in 2039...
# Fetching holidays for denmark in 2040...
# Fetching holidays for finland in 2021...
# Fetching holidays for finland in 2022...
# Fetching holidays for finland in 2023...
# Fetching holidays for finland in 2024...
# Fetching holidays for finland in 2025...
# Fetching holidays for finland in 2026...
# Fetching holidays for finland in 2027...
# Fetching holidays for finland in 2028...
# Fetching holidays for finland in 2029...
# Fetching holidays for finland in 2030...
# Fetching holidays for finland in 2031...
# Fetching holidays for finland in 2032...
# Fetching holidays for finland in 2033...
# Fetching holidays for finland in 2034...
# Fetching holidays for finland in 2035...
# Fetching holidays for finland in 2036...
# Fetching holidays for finland in 2037...
# Fetching holidays for finland in 2038...
# Fetching holidays for finland in 2039...
# Fetching holidays for finland in 2040...
# Fetching holidays for france in 2021...
# Fetching holidays for france in 2022...
# Fetching holidays for france in 2023...
# Fetching holidays for france in 2024...
# Fetching holidays for france in 2025...
# Fetching holidays for france in 2026...
# Fetching holidays for france in 2027...
# Fetching holidays for france in 2028...
# Fetching holidays for france in 2029...
# Fetching holidays for france in 2030...
# Fetching holidays for france in 2031...
# Fetching holidays for france in 2032...
# Fetching holidays for france in 2033...
# Fetching holidays for france in 2034...
# Fetching holidays for france in 2035...
# Fetching holidays for france in 2036...
# Fetching holidays for france in 2037...
# Fetching holidays for france in 2038...
# Fetching holidays for france in 2039...
# Fetching holidays for france in 2040...
#            Date        Day                                 Name  \
# 0    1 Jan 2021     Friday                       New Year's Day
# 1    2 Jan 2021   Saturday                   New Year's Holiday
# 2    3 Jan 2021     Sunday                   New Year's Holiday
# 3    7 Feb 2021     Sunday                  Special Working Day
# 4   11 Feb 2021   Thursday                  Spring Festival Eve
# 5   12 Feb 2021     Friday                     Chinese New Year
# 6   13 Feb 2021   Saturday  Spring Festival Golden Week holiday
# 7   14 Feb 2021     Sunday  Spring Festival Golden Week holiday
# 8   15 Feb 2021     Monday  Spring Festival Golden Week holiday
# 9   16 Feb 2021    Tuesday  Spring Festival Golden Week holiday
# 10  17 Feb 2021  Wednesday  Spring Festival Golden Week holiday
# 11  20 Feb 2021   Saturday                  Special Working Day
# 12  26 Feb 2021     Friday                     Lantern Festival
# 13   8 Mar 2021     Monday            International Women's Day
# 14  12 Mar 2021     Friday                            Arbor Day
#
#                         Type Country
# 0           National Holiday   china
# 1           National Holiday   china
# 2           National Holiday   china
# 3   Working Day on a Weekend   china
# 4           National Holiday   china
# 5           National Holiday   china
# 6           National Holiday   china
# 7           National Holiday   china
# 8           National Holiday   china
# 9           National Holiday   china
# 10          National Holiday   china
# 11  Working Day on a Weekend   china
# 12                Observance   china
# 13          Half day holiday   china
# 14                Observance   china

# %% [markdown]
# 'germany',
# 'greece',
# 'hong-kong',
# 'hungary',
# 'india'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['germany', 'greece', 'hong-kong', 'hungary', 'india']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_3.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for germany in 2021...
# Fetching holidays for germany in 2022...
# Fetching holidays for germany in 2023...
# Fetching holidays for germany in 2024...
# Fetching holidays for germany in 2025...
# Fetching holidays for germany in 2026...
# Fetching holidays for germany in 2027...
# Fetching holidays for germany in 2028...
# Fetching holidays for germany in 2029...
# Fetching holidays for germany in 2030...
# Fetching holidays for germany in 2031...
# Fetching holidays for germany in 2032...
# Fetching holidays for germany in 2033...
# Fetching holidays for germany in 2034...
# Fetching holidays for germany in 2035...
# Fetching holidays for germany in 2036...
# Fetching holidays for germany in 2037...
# Fetching holidays for germany in 2038...
# Fetching holidays for germany in 2039...
# Fetching holidays for germany in 2040...
# Fetching holidays for greece in 2021...
# Fetching holidays for greece in 2022...
# Fetching holidays for greece in 2023...
# Fetching holidays for greece in 2024...
# Fetching holidays for greece in 2025...
# Fetching holidays for greece in 2026...
# Fetching holidays for greece in 2027...
# Fetching holidays for greece in 2028...
# Fetching holidays for greece in 2029...
# Fetching holidays for greece in 2030...
# Fetching holidays for greece in 2031...
# Fetching holidays for greece in 2032...
# Fetching holidays for greece in 2033...
# Fetching holidays for greece in 2034...
# Fetching holidays for greece in 2035...
# Fetching holidays for greece in 2036...
# Fetching holidays for greece in 2037...
# Fetching holidays for greece in 2038...
# Fetching holidays for greece in 2039...
# Fetching holidays for greece in 2040...
# Fetching holidays for hong-kong in 2021...
# Fetching holidays for hong-kong in 2022...
# Fetching holidays for hong-kong in 2023...
# Fetching holidays for hong-kong in 2024...
# Fetching holidays for hong-kong in 2025...
# Fetching holidays for hong-kong in 2026...
# Fetching holidays for hong-kong in 2027...
# Fetching holidays for hong-kong in 2028...
# Fetching holidays for hong-kong in 2029...
# Fetching holidays for hong-kong in 2030...
# Fetching holidays for hong-kong in 2031...
# Fetching holidays for hong-kong in 2032...
# Fetching holidays for hong-kong in 2033...
# Fetching holidays for hong-kong in 2034...
# Fetching holidays for hong-kong in 2035...
# Fetching holidays for hong-kong in 2036...
# Fetching holidays for hong-kong in 2037...
# Fetching holidays for hong-kong in 2038...
# Fetching holidays for hong-kong in 2039...
# Fetching holidays for hong-kong in 2040...
# Fetching holidays for hungary in 2021...
# Fetching holidays for hungary in 2022...
# Fetching holidays for hungary in 2023...
# Fetching holidays for hungary in 2024...
# Fetching holidays for hungary in 2025...
# Fetching holidays for hungary in 2026...
# Fetching holidays for hungary in 2027...
# Fetching holidays for hungary in 2028...
# Fetching holidays for hungary in 2029...
# Fetching holidays for hungary in 2030...
# Fetching holidays for hungary in 2031...
# Fetching holidays for hungary in 2032...
# Fetching holidays for hungary in 2033...
# Fetching holidays for hungary in 2034...
# Fetching holidays for hungary in 2035...
# Fetching holidays for hungary in 2036...
# Fetching holidays for hungary in 2037...
# Fetching holidays for hungary in 2038...
# Fetching holidays for hungary in 2039...
# Fetching holidays for hungary in 2040...
# Fetching holidays for india in 2021...
# Fetching holidays for india in 2022...
# Fetching holidays for india in 2023...
# Fetching holidays for india in 2024...
# Fetching holidays for india in 2025...
# Fetching holidays for india in 2026...
# Fetching holidays for india in 2027...
# Fetching holidays for india in 2028...
# Fetching holidays for india in 2029...
# Fetching holidays for india in 2030...
# Fetching holidays for india in 2031...
# Fetching holidays for india in 2032...
# Fetching holidays for india in 2033...
# Fetching holidays for india in 2034...
# Fetching holidays for india in 2035...
# Fetching holidays for india in 2036...
# Fetching holidays for india in 2037...
# Fetching holidays for india in 2038...
# Fetching holidays for india in 2039...
# Fetching holidays for india in 2040...
#            Date        Day                                               Name  \
# 0    1 Jan 2021     Friday                                     New Year's Day
# 1    6 Jan 2021  Wednesday                                           Epiphany
# 2    6 Jan 2021  Wednesday                                           Epiphany
# 3   22 Jan 2021     Friday                                  Franco-German Day
# 4   27 Jan 2021  Wednesday  Remembrance Day for the Victims of National So...
# 5   14 Feb 2021     Sunday                                    Valentine's Day
# 6   15 Feb 2021     Monday                                      Shrove Monday
# 7   16 Feb 2021    Tuesday                                   Carnival Tuesday
# 8   16 Feb 2021    Tuesday                                         Hizir Fast
# 9   17 Feb 2021  Wednesday                           Carnival / Ash Wednesday
# 10   8 Mar 2021     Monday                          International Women's Day
# 11   8 Mar 2021     Monday                          International Women's Day
# 12  17 Mar 2021  Wednesday                                  St. Patrick's Day
# 13  18 Mar 2021   Thursday                Anniversary of the March Revolution
# 14  20 Mar 2021   Saturday                                      March Equinox
#
#                      Type  Country
# 0        National Holiday  germany
# 1   Observance, Christian  germany
# 2    Common Local Holiday  germany
# 3              Observance  germany
# 4              Observance  germany
# 5              Observance  germany
# 6   Observance, Christian  germany
# 7              Observance  germany
# 8      Observance, Muslim  germany
# 9              Silent Day  germany
# 10             Observance  germany
# 11   Common Local Holiday  germany
# 12  Observance, Christian  germany
# 13             Observance  germany
# 14                 Season  germany

# %% [markdown]
# 'indonesia',
# 'israel',
# 'italy',
# 'japan',
# 'kenya'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['indonesia', 'israel', 'italy', 'japan', 'kenya']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_4.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for indonesia in 2021...
# Fetching holidays for indonesia in 2022...
# Fetching holidays for indonesia in 2023...
# Fetching holidays for indonesia in 2024...
# Fetching holidays for indonesia in 2025...
# Fetching holidays for indonesia in 2026...
# No holiday table found for indonesia 2026
# Fetching holidays for indonesia in 2027...
# No holiday table found for indonesia 2027
# Fetching holidays for indonesia in 2028...
# No holiday table found for indonesia 2028
# Fetching holidays for indonesia in 2029...
# No holiday table found for indonesia 2029
# Fetching holidays for indonesia in 2030...
# No holiday table found for indonesia 2030
# Fetching holidays for indonesia in 2031...
# No holiday table found for indonesia 2031
# Fetching holidays for indonesia in 2032...
# No holiday table found for indonesia 2032
# Fetching holidays for indonesia in 2033...
# No holiday table found for indonesia 2033
# Fetching holidays for indonesia in 2034...
# No holiday table found for indonesia 2034
# Fetching holidays for indonesia in 2035...
# No holiday table found for indonesia 2035
# Fetching holidays for indonesia in 2036...
# No holiday table found for indonesia 2036
# Fetching holidays for indonesia in 2037...
# No holiday table found for indonesia 2037
# Fetching holidays for indonesia in 2038...
# No holiday table found for indonesia 2038
# Fetching holidays for indonesia in 2039...
# No holiday table found for indonesia 2039
# Fetching holidays for indonesia in 2040...
# No holiday table found for indonesia 2040
# Fetching holidays for israel in 2021...
# Fetching holidays for israel in 2022...
# Fetching holidays for israel in 2023...
# Fetching holidays for israel in 2024...
# Fetching holidays for israel in 2025...
# Fetching holidays for israel in 2026...
# Fetching holidays for israel in 2027...
# Fetching holidays for israel in 2028...
# Fetching holidays for israel in 2029...
# Fetching holidays for israel in 2030...
# Fetching holidays for israel in 2031...
# Fetching holidays for israel in 2032...
# Fetching holidays for israel in 2033...
# Fetching holidays for israel in 2034...
# Fetching holidays for israel in 2035...
# Fetching holidays for israel in 2036...
# Fetching holidays for israel in 2037...
# Fetching holidays for israel in 2038...
# Fetching holidays for israel in 2039...
# Fetching holidays for israel in 2040...
# Fetching holidays for italy in 2021...
# Fetching holidays for italy in 2022...
# Fetching holidays for italy in 2023...
# Fetching holidays for italy in 2024...
# Fetching holidays for italy in 2025...
# Fetching holidays for italy in 2026...
# Fetching holidays for italy in 2027...
# Fetching holidays for italy in 2028...
# Fetching holidays for italy in 2029...
# Fetching holidays for italy in 2030...
# Fetching holidays for italy in 2031...
# Fetching holidays for italy in 2032...
# Fetching holidays for italy in 2033...
# Fetching holidays for italy in 2034...
# Fetching holidays for italy in 2035...
# Fetching holidays for italy in 2036...
# Fetching holidays for italy in 2037...
# Fetching holidays for italy in 2038...
# Fetching holidays for italy in 2039...
# Fetching holidays for italy in 2040...
# Fetching holidays for japan in 2021...
# Fetching holidays for japan in 2022...
# Fetching holidays for japan in 2023...
# Fetching holidays for japan in 2024...
# Fetching holidays for japan in 2025...
# Fetching holidays for japan in 2026...
# Fetching holidays for japan in 2027...
# Fetching holidays for japan in 2028...
# Fetching holidays for japan in 2029...
# Fetching holidays for japan in 2030...
# Fetching holidays for japan in 2031...
# Fetching holidays for japan in 2032...
# Fetching holidays for japan in 2033...
# Fetching holidays for japan in 2034...
# Fetching holidays for japan in 2035...
# Fetching holidays for japan in 2036...
# Fetching holidays for japan in 2037...
# Fetching holidays for japan in 2038...
# Fetching holidays for japan in 2039...
# Fetching holidays for japan in 2040...
# Fetching holidays for kenya in 2021...
# Fetching holidays for kenya in 2022...
# Fetching holidays for kenya in 2023...
# Fetching holidays for kenya in 2024...
# Fetching holidays for kenya in 2025...
# Fetching holidays for kenya in 2026...
# Fetching holidays for kenya in 2027...
# Fetching holidays for kenya in 2028...
# Fetching holidays for kenya in 2029...
# Fetching holidays for kenya in 2030...
# Fetching holidays for kenya in 2031...
# Fetching holidays for kenya in 2032...
# Fetching holidays for kenya in 2033...
# Fetching holidays for kenya in 2034...
# Fetching holidays for kenya in 2035...
# Fetching holidays for kenya in 2036...
# Fetching holidays for kenya in 2037...
# Fetching holidays for kenya in 2038...
# Fetching holidays for kenya in 2039...
# Fetching holidays for kenya in 2040...
#            Date        Day                                              Name  \
# 0    1 Jan 2021     Friday                                    New Year's Day
# 1   12 Feb 2021     Friday                            Chinese New Year's Day
# 2   11 Mar 2021   Thursday                                   Maha Shivaratri
# 3   11 Mar 2021   Thursday                 Ascension of the Prophet Muhammad
# 4   12 Mar 2021     Friday                      Joint Holiday (Cuti Bersama)
# 5   14 Mar 2021     Sunday  Bali's Day of Silence and Hindu New Year (Nyepi)
# 6   20 Mar 2021   Saturday                                     March Equinox
# 7   29 Mar 2021     Monday                                              Holi
# 8    2 Apr 2021     Friday                                       Good Friday
# 9    4 Apr 2021     Sunday                                     Easter Sunday
# 10   1 May 2021   Saturday                           International Labor Day
# 11  12 May 2021  Wednesday                          Idul Fitri Joint Holiday
# 12  13 May 2021   Thursday                                        Idul Fitri
# 13  13 May 2021   Thursday                     Ascension Day of Jesus Christ
# 14  14 May 2021     Friday                                Idul Fitri Holiday
#
#               Type    Country
# 0   Public Holiday  indonesia
# 1   Public Holiday  indonesia
# 2    Hindu Holiday  indonesia
# 3   Public Holiday  indonesia
# 4    Joint Holiday  indonesia
# 5   Public Holiday  indonesia
# 6           Season  indonesia
# 7    Hindu Holiday  indonesia
# 8   Public Holiday  indonesia
# 9       Observance  indonesia
# 10  Public Holiday  indonesia
# 11   Joint Holiday  indonesia
# 12  Public Holiday  indonesia
# 13  Public Holiday  indonesia
# 14  Public Holiday  indonesia

# %% [markdown]
# north-korea',
# south-korea',
# 'malaysia',
# 'mongolia',
# 'morocco'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['north-korea', 'south-korea', 'malaysia', 'mongolia', 'morocco']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_5.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for north-korea in 2021...
# Fetching holidays for north-korea in 2022...
# Fetching holidays for north-korea in 2023...
# Fetching holidays for north-korea in 2024...
# Fetching holidays for north-korea in 2025...
# Fetching holidays for north-korea in 2026...
# Fetching holidays for north-korea in 2027...
# Fetching holidays for north-korea in 2028...
# Fetching holidays for north-korea in 2029...
# Fetching holidays for north-korea in 2030...
# Fetching holidays for north-korea in 2031...
# Fetching holidays for north-korea in 2032...
# Fetching holidays for north-korea in 2033...
# Fetching holidays for north-korea in 2034...
# Fetching holidays for north-korea in 2035...
# Fetching holidays for north-korea in 2036...
# Fetching holidays for north-korea in 2037...
# Fetching holidays for north-korea in 2038...
# Fetching holidays for north-korea in 2039...
# Fetching holidays for north-korea in 2040...
# Fetching holidays for south-korea in 2021...
# Fetching holidays for south-korea in 2022...
# Fetching holidays for south-korea in 2023...
# Fetching holidays for south-korea in 2024...
# Fetching holidays for south-korea in 2025...
# Fetching holidays for south-korea in 2026...
# Fetching holidays for south-korea in 2027...
# Fetching holidays for south-korea in 2028...
# Fetching holidays for south-korea in 2029...
# Fetching holidays for south-korea in 2030...
# Fetching holidays for south-korea in 2031...
# Fetching holidays for south-korea in 2032...
# Fetching holidays for south-korea in 2033...
# Fetching holidays for south-korea in 2034...
# Fetching holidays for south-korea in 2035...
# Fetching holidays for south-korea in 2036...
# Fetching holidays for south-korea in 2037...
# Fetching holidays for south-korea in 2038...
# Fetching holidays for south-korea in 2039...
# Fetching holidays for south-korea in 2040...
# Fetching holidays for malaysia in 2021...
# Fetching holidays for malaysia in 2022...
# Fetching holidays for malaysia in 2023...
# Fetching holidays for malaysia in 2024...
# Fetching holidays for malaysia in 2025...
# Fetching holidays for malaysia in 2026...
# Fetching holidays for malaysia in 2027...
# Fetching holidays for malaysia in 2028...
# Fetching holidays for malaysia in 2029...
# Fetching holidays for malaysia in 2030...
# Fetching holidays for malaysia in 2031...
# Fetching holidays for malaysia in 2032...
# Fetching holidays for malaysia in 2033...
# Fetching holidays for malaysia in 2034...
# Fetching holidays for malaysia in 2035...
# Fetching holidays for malaysia in 2036...
# Fetching holidays for malaysia in 2037...
# Fetching holidays for malaysia in 2038...
# Fetching holidays for malaysia in 2039...
# Fetching holidays for malaysia in 2040...
# Fetching holidays for mongolia in 2021...
# Fetching holidays for mongolia in 2022...
# Fetching holidays for mongolia in 2023...
# Fetching holidays for mongolia in 2024...
# Fetching holidays for mongolia in 2025...
# Fetching holidays for mongolia in 2026...
# Fetching holidays for mongolia in 2027...
# Fetching holidays for mongolia in 2028...
# Fetching holidays for mongolia in 2029...
# Fetching holidays for mongolia in 2030...
# Fetching holidays for mongolia in 2031...
# Fetching holidays for mongolia in 2032...
# Fetching holidays for mongolia in 2033...
# Fetching holidays for mongolia in 2034...
# Fetching holidays for mongolia in 2035...
# Fetching holidays for mongolia in 2036...
# Fetching holidays for mongolia in 2037...
# Fetching holidays for mongolia in 2038...
# Fetching holidays for mongolia in 2039...
# Fetching holidays for mongolia in 2040...
# Fetching holidays for morocco in 2021...
# Fetching holidays for morocco in 2022...
# Fetching holidays for morocco in 2023...
# Fetching holidays for morocco in 2024...
# Fetching holidays for morocco in 2025...
# Fetching holidays for morocco in 2026...
# Fetching holidays for morocco in 2027...
# Fetching holidays for morocco in 2028...
# Fetching holidays for morocco in 2029...
# Fetching holidays for morocco in 2030...
# Fetching holidays for morocco in 2031...
# Fetching holidays for morocco in 2032...
# Fetching holidays for morocco in 2033...
# Fetching holidays for morocco in 2034...
# Fetching holidays for morocco in 2035...
# Fetching holidays for morocco in 2036...
# Fetching holidays for morocco in 2037...
# Fetching holidays for morocco in 2038...
# Fetching holidays for morocco in 2039...
# Fetching holidays for morocco in 2040...
#            Date        Day                                             Name  \
# 0    1 Jan 2021     Friday                                         New Year
# 1   12 Feb 2021     Friday                                          Seollal
# 2   16 Feb 2021    Tuesday                        Birth date of Kim Jong Il
# 3   26 Feb 2021     Friday                               Cheongwoldaeboreum
# 4    8 Mar 2021     Monday                        International Women's Day
# 5   20 Mar 2021   Saturday                                    March Equinox
# 6   15 Apr 2021   Thursday                        Birth Date of Kim Il Sung
# 7   25 Apr 2021     Sunday              Chosun People's Army Foundation Day
# 8    1 May 2021   Saturday                                          May Day
# 9    6 Jun 2021     Sunday           Chosun Children's Union Foundation Day
# 10  21 Jun 2021     Monday                                    June Solstice
# 11  27 Jul 2021    Tuesday  Day of Victory in the Fatherland Liberation War
# 12  15 Aug 2021     Sunday                                   Liberation Day
# 13  25 Aug 2021  Wednesday                                    Day of Songun
# 14   9 Sep 2021   Thursday                                     National Day
#
#               Type      Country
# 0   Public Holiday  north-korea
# 1   Public Holiday  north-korea
# 2   Public Holiday  north-korea
# 3   Public Holiday  north-korea
# 4   Public Holiday  north-korea
# 5           Season  north-korea
# 6   Public Holiday  north-korea
# 7   Public Holiday  north-korea
# 8   Public Holiday  north-korea
# 9   Public Holiday  north-korea
# 10          Season  north-korea
# 11  Public Holiday  north-korea
# 12  Public Holiday  north-korea
# 13  Public Holiday  north-korea
# 14  Public Holiday  north-korea

# %% [markdown]
# 'netherlands',
# 'norway',
# 'pakistan',
# 'philippines',
# 'poland'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['netherlands', 'norway', 'pakistan', 'philippines', 'poland']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_6.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for netherlands in 2021...
# Fetching holidays for netherlands in 2022...
# Fetching holidays for netherlands in 2023...
# Fetching holidays for netherlands in 2024...
# Fetching holidays for netherlands in 2025...
# Fetching holidays for netherlands in 2026...
# Fetching holidays for netherlands in 2027...
# Fetching holidays for netherlands in 2028...
# Fetching holidays for netherlands in 2029...
# Fetching holidays for netherlands in 2030...
# Fetching holidays for netherlands in 2031...
# Fetching holidays for netherlands in 2032...
# Fetching holidays for netherlands in 2033...
# Fetching holidays for netherlands in 2034...
# Fetching holidays for netherlands in 2035...
# Fetching holidays for netherlands in 2036...
# Fetching holidays for netherlands in 2037...
# Fetching holidays for netherlands in 2038...
# Fetching holidays for netherlands in 2039...
# Fetching holidays for netherlands in 2040...
# Fetching holidays for norway in 2021...
# Fetching holidays for norway in 2022...
# Fetching holidays for norway in 2023...
# Fetching holidays for norway in 2024...
# Fetching holidays for norway in 2025...
# Fetching holidays for norway in 2026...
# Fetching holidays for norway in 2027...
# Fetching holidays for norway in 2028...
# Fetching holidays for norway in 2029...
# Fetching holidays for norway in 2030...
# Fetching holidays for norway in 2031...
# Fetching holidays for norway in 2032...
# Fetching holidays for norway in 2033...
# Fetching holidays for norway in 2034...
# Fetching holidays for norway in 2035...
# Fetching holidays for norway in 2036...
# Fetching holidays for norway in 2037...
# Fetching holidays for norway in 2038...
# Fetching holidays for norway in 2039...
# Fetching holidays for norway in 2040...
# Fetching holidays for pakistan in 2021...
# Fetching holidays for pakistan in 2022...
# Fetching holidays for pakistan in 2023...
# Fetching holidays for pakistan in 2024...
# Fetching holidays for pakistan in 2025...
# Fetching holidays for pakistan in 2026...
# No holiday table found for pakistan 2026
# Fetching holidays for pakistan in 2027...
# No holiday table found for pakistan 2027
# Fetching holidays for pakistan in 2028...
# No holiday table found for pakistan 2028
# Fetching holidays for pakistan in 2029...
# No holiday table found for pakistan 2029
# Fetching holidays for pakistan in 2030...
# No holiday table found for pakistan 2030
# Fetching holidays for pakistan in 2031...
# No holiday table found for pakistan 2031
# Fetching holidays for pakistan in 2032...
# No holiday table found for pakistan 2032
# Fetching holidays for pakistan in 2033...
# No holiday table found for pakistan 2033
# Fetching holidays for pakistan in 2034...
# No holiday table found for pakistan 2034
# Fetching holidays for pakistan in 2035...
# No holiday table found for pakistan 2035
# Fetching holidays for pakistan in 2036...
# No holiday table found for pakistan 2036
# Fetching holidays for pakistan in 2037...
# No holiday table found for pakistan 2037
# Fetching holidays for pakistan in 2038...
# No holiday table found for pakistan 2038
# Fetching holidays for pakistan in 2039...
# No holiday table found for pakistan 2039
# Fetching holidays for pakistan in 2040...
# No holiday table found for pakistan 2040
# Fetching holidays for philippines in 2021...
# Fetching holidays for philippines in 2022...
# Fetching holidays for philippines in 2023...
# Fetching holidays for philippines in 2024...
# Fetching holidays for philippines in 2025...
# Fetching holidays for philippines in 2026...
# Fetching holidays for philippines in 2027...
# Fetching holidays for philippines in 2028...
# Fetching holidays for philippines in 2029...
# Fetching holidays for philippines in 2030...
# Fetching holidays for philippines in 2031...
# Fetching holidays for philippines in 2032...
# Fetching holidays for philippines in 2033...
# Fetching holidays for philippines in 2034...
# Fetching holidays for philippines in 2035...
# Fetching holidays for philippines in 2036...
# Fetching holidays for philippines in 2037...
# Fetching holidays for philippines in 2038...
# Fetching holidays for philippines in 2039...
# Fetching holidays for philippines in 2040...
# Fetching holidays for poland in 2021...
# Fetching holidays for poland in 2022...
# Fetching holidays for poland in 2023...
# Fetching holidays for poland in 2024...
# Fetching holidays for poland in 2025...
# Fetching holidays for poland in 2026...
# Fetching holidays for poland in 2027...
# Fetching holidays for poland in 2028...
# Fetching holidays for poland in 2029...
# Fetching holidays for poland in 2030...
# Fetching holidays for poland in 2031...
# Fetching holidays for poland in 2032...
# Fetching holidays for poland in 2033...
# Fetching holidays for poland in 2034...
# Fetching holidays for poland in 2035...
# Fetching holidays for poland in 2036...
# Fetching holidays for poland in 2037...
# Fetching holidays for poland in 2038...
# Fetching holidays for poland in 2039...
# Fetching holidays for poland in 2040...
#            Date        Day             Name            Type      Country
# 0    1 Jan 2021     Friday   New Year's Day  Public Holiday  netherlands
# 1   14 Feb 2021     Sunday  Valentine's Day      Observance  netherlands
# 2   20 Mar 2021   Saturday    March Equinox          Season  netherlands
# 3    2 Apr 2021     Friday      Good Friday  Public Holiday  netherlands
# 4    4 Apr 2021     Sunday    Easter Sunday  Public Holiday  netherlands
# 5    5 Apr 2021     Monday    Easter Monday  Public Holiday  netherlands
# 6   27 Apr 2021    Tuesday  King's Birthday  Public Holiday  netherlands
# 7    4 May 2021    Tuesday  Remembrance Day      Observance  netherlands
# 8    5 May 2021  Wednesday   Liberation Day   Public Sector  netherlands
# 9    9 May 2021     Sunday     Mother's Day      Observance  netherlands
# 10  13 May 2021   Thursday    Ascension Day  Public Holiday  netherlands
# 11  23 May 2021     Sunday      Whit Sunday  Public Holiday  netherlands
# 12  24 May 2021     Monday      Whit Monday  Public Holiday  netherlands
# 13  20 Jun 2021     Sunday     Father's Day      Observance  netherlands
# 14  21 Jun 2021     Monday    June Solstice          Season  netherlands

# %% [markdown]
# 'portugal',
# 'romania',
# 'russia',
# 'slovenia',
# 'south-africa'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['portugal', 'romania', 'russia', 'slovenia', 'south-africa']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_7.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for portugal in 2021...
# Fetching holidays for portugal in 2022...
# Fetching holidays for portugal in 2023...
# Fetching holidays for portugal in 2024...
# Fetching holidays for portugal in 2025...
# Fetching holidays for portugal in 2026...
# Fetching holidays for portugal in 2027...
# Fetching holidays for portugal in 2028...
# Fetching holidays for portugal in 2029...
# Fetching holidays for portugal in 2030...
# Fetching holidays for portugal in 2031...
# Fetching holidays for portugal in 2032...
# Fetching holidays for portugal in 2033...
# Fetching holidays for portugal in 2034...
# Fetching holidays for portugal in 2035...
# Fetching holidays for portugal in 2036...
# Fetching holidays for portugal in 2037...
# Fetching holidays for portugal in 2038...
# Fetching holidays for portugal in 2039...
# Fetching holidays for portugal in 2040...
# Fetching holidays for romania in 2021...
# Fetching holidays for romania in 2022...
# Fetching holidays for romania in 2023...
# Fetching holidays for romania in 2024...
# Fetching holidays for romania in 2025...
# Fetching holidays for romania in 2026...
# Fetching holidays for romania in 2027...
# Fetching holidays for romania in 2028...
# Fetching holidays for romania in 2029...
# Fetching holidays for romania in 2030...
# Fetching holidays for romania in 2031...
# Fetching holidays for romania in 2032...
# Fetching holidays for romania in 2033...
# Fetching holidays for romania in 2034...
# Fetching holidays for romania in 2035...
# Fetching holidays for romania in 2036...
# Fetching holidays for romania in 2037...
# Fetching holidays for romania in 2038...
# Fetching holidays for romania in 2039...
# Fetching holidays for romania in 2040...
# Fetching holidays for russia in 2021...
# Fetching holidays for russia in 2022...
# Fetching holidays for russia in 2023...
# Fetching holidays for russia in 2024...
# Fetching holidays for russia in 2025...
# Fetching holidays for russia in 2026...
# Fetching holidays for russia in 2027...
# Fetching holidays for russia in 2028...
# Fetching holidays for russia in 2029...
# Fetching holidays for russia in 2030...
# Fetching holidays for russia in 2031...
# Fetching holidays for russia in 2032...
# Fetching holidays for russia in 2033...
# Fetching holidays for russia in 2034...
# Fetching holidays for russia in 2035...
# Fetching holidays for russia in 2036...
# Fetching holidays for russia in 2037...
# Fetching holidays for russia in 2038...
# Fetching holidays for russia in 2039...
# Fetching holidays for russia in 2040...
# Fetching holidays for slovenia in 2021...
# Fetching holidays for slovenia in 2022...
# Fetching holidays for slovenia in 2023...
# Fetching holidays for slovenia in 2024...
# Fetching holidays for slovenia in 2025...
# Fetching holidays for slovenia in 2026...
# Fetching holidays for slovenia in 2027...
# Fetching holidays for slovenia in 2028...
# Fetching holidays for slovenia in 2029...
# Fetching holidays for slovenia in 2030...
# Fetching holidays for slovenia in 2031...
# Fetching holidays for slovenia in 2032...
# Fetching holidays for slovenia in 2033...
# Fetching holidays for slovenia in 2034...
# Fetching holidays for slovenia in 2035...
# Fetching holidays for slovenia in 2036...
# Fetching holidays for slovenia in 2037...
# Fetching holidays for slovenia in 2038...
# Error fetching holidays for slovenia 2038: HTTPSConnectionPool(host='www.timeanddate.com', port=443): Max retries exceeded with url: /holidays/slovenia/2038?hl=en (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002D3416FFFE0>: Failed to resolve 'www.timeanddate.com' ([Errno 11001] getaddrinfo failed)"))
# Fetching holidays for slovenia in 2039...
# Fetching holidays for slovenia in 2040...
# Fetching holidays for south-africa in 2021...
# Fetching holidays for south-africa in 2022...
# Fetching holidays for south-africa in 2023...
# Fetching holidays for south-africa in 2024...
# Fetching holidays for south-africa in 2025...
# Fetching holidays for south-africa in 2026...
# Fetching holidays for south-africa in 2027...
# Fetching holidays for south-africa in 2028...
# Fetching holidays for south-africa in 2029...
# Fetching holidays for south-africa in 2030...
# Fetching holidays for south-africa in 2031...
# Fetching holidays for south-africa in 2032...
# Fetching holidays for south-africa in 2033...
# Fetching holidays for south-africa in 2034...
# Fetching holidays for south-africa in 2035...
# Fetching holidays for south-africa in 2036...
# Fetching holidays for south-africa in 2037...
# Fetching holidays for south-africa in 2038...
# Fetching holidays for south-africa in 2039...
# Fetching holidays for south-africa in 2040...
#            Date        Day                                     Name  \
# 0    1 Jan 2021     Friday                           New Year's Day
# 1   14 Feb 2021     Sunday                          Valentine's Day
# 2   16 Feb 2021    Tuesday  Carnival / Shrove Tuesday / Pancake Day
# 3   19 Mar 2021     Friday                         St. Joseph's Day
# 4   19 Mar 2021     Friday                             Fathers' Day
# 5   20 Mar 2021   Saturday                            March Equinox
# 6   28 Mar 2021     Sunday              Daylight Saving Time starts
# 7    2 Apr 2021     Friday                              Good Friday
# 8    4 Apr 2021     Sunday                            Easter Sunday
# 9   20 Apr 2021    Tuesday                     Our Lady of Mércoles
# 10  25 Apr 2021     Sunday                              Liberty Day
# 11   1 May 2021   Saturday                      Labor Day / May Day
# 12   2 May 2021     Sunday                             Mothers' Day
# 13  12 May 2021  Wednesday                          St. Joana's Day
# 14  13 May 2021   Thursday                            Ascension Day
#
#                                  Type   Country
# 0                    National Holiday  portugal
# 1                          Observance  portugal
# 2                    Optional Holiday  portugal
# 3                    District Holiday  portugal
# 4                          Observance  portugal
# 5                              Season  portugal
# 6   Clock Change/Daylight Saving Time  portugal
# 7                    National Holiday  portugal
# 8                    National Holiday  portugal
# 9                    District Holiday  portugal
# 10                   National Holiday  portugal
# 11                   National Holiday  portugal
# 12                         Observance  portugal
# 13                   District Holiday  portugal
# 14                   District Holiday  portugal

# %% [markdown]
# 'spain',
# 'sri-lanka',
# 'sweden',
# 'taiwan',
# 'thailand'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['spain', 'sri-lanka', 'sweden', 'taiwan', 'thailand']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_8.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for spain in 2021...
# Fetching holidays for spain in 2022...
# Fetching holidays for spain in 2023...
# Fetching holidays for spain in 2024...
# Fetching holidays for spain in 2025...
# Fetching holidays for spain in 2026...
# Fetching holidays for spain in 2027...
# Fetching holidays for spain in 2028...
# Fetching holidays for spain in 2029...
# Fetching holidays for spain in 2030...
# Fetching holidays for spain in 2031...
# Fetching holidays for spain in 2032...
# Fetching holidays for spain in 2033...
# Fetching holidays for spain in 2034...
# Fetching holidays for spain in 2035...
# Fetching holidays for spain in 2036...
# Fetching holidays for spain in 2037...
# Fetching holidays for spain in 2038...
# Fetching holidays for spain in 2039...
# Fetching holidays for spain in 2040...
# Fetching holidays for sri-lanka in 2021...
# Fetching holidays for sri-lanka in 2022...
# Fetching holidays for sri-lanka in 2023...
# Fetching holidays for sri-lanka in 2024...
# Fetching holidays for sri-lanka in 2025...
# Fetching holidays for sri-lanka in 2026...
# No holiday table found for sri-lanka 2026
# Fetching holidays for sri-lanka in 2027...
# No holiday table found for sri-lanka 2027
# Fetching holidays for sri-lanka in 2028...
# No holiday table found for sri-lanka 2028
# Fetching holidays for sri-lanka in 2029...
# No holiday table found for sri-lanka 2029
# Fetching holidays for sri-lanka in 2030...
# No holiday table found for sri-lanka 2030
# Fetching holidays for sri-lanka in 2031...
# No holiday table found for sri-lanka 2031
# Fetching holidays for sri-lanka in 2032...
# No holiday table found for sri-lanka 2032
# Fetching holidays for sri-lanka in 2033...
# No holiday table found for sri-lanka 2033
# Fetching holidays for sri-lanka in 2034...
# No holiday table found for sri-lanka 2034
# Fetching holidays for sri-lanka in 2035...
# No holiday table found for sri-lanka 2035
# Fetching holidays for sri-lanka in 2036...
# No holiday table found for sri-lanka 2036
# Fetching holidays for sri-lanka in 2037...
# No holiday table found for sri-lanka 2037
# Fetching holidays for sri-lanka in 2038...
# No holiday table found for sri-lanka 2038
# Fetching holidays for sri-lanka in 2039...
# No holiday table found for sri-lanka 2039
# Fetching holidays for sri-lanka in 2040...
# No holiday table found for sri-lanka 2040
# Fetching holidays for sweden in 2021...
# Fetching holidays for sweden in 2022...
# Fetching holidays for sweden in 2023...
# Fetching holidays for sweden in 2024...
# Fetching holidays for sweden in 2025...
# Fetching holidays for sweden in 2026...
# Fetching holidays for sweden in 2027...
# Fetching holidays for sweden in 2028...
# Fetching holidays for sweden in 2029...
# Fetching holidays for sweden in 2030...
# Fetching holidays for sweden in 2031...
# Fetching holidays for sweden in 2032...
# Fetching holidays for sweden in 2033...
# Fetching holidays for sweden in 2034...
# Fetching holidays for sweden in 2035...
# Fetching holidays for sweden in 2036...
# Fetching holidays for sweden in 2037...
# Fetching holidays for sweden in 2038...
# Fetching holidays for sweden in 2039...
# Fetching holidays for sweden in 2040...
# Fetching holidays for taiwan in 2021...
# Fetching holidays for taiwan in 2022...
# Fetching holidays for taiwan in 2023...
# Fetching holidays for taiwan in 2024...
# Fetching holidays for taiwan in 2025...
# Fetching holidays for taiwan in 2026...
# Fetching holidays for taiwan in 2027...
# Fetching holidays for taiwan in 2028...
# Fetching holidays for taiwan in 2029...
# Fetching holidays for taiwan in 2030...
# Fetching holidays for taiwan in 2031...
# Fetching holidays for taiwan in 2032...
# Fetching holidays for taiwan in 2033...
# Fetching holidays for taiwan in 2034...
# Fetching holidays for taiwan in 2035...
# Fetching holidays for taiwan in 2036...
# Fetching holidays for taiwan in 2037...
# Fetching holidays for taiwan in 2038...
# Fetching holidays for taiwan in 2039...
# Fetching holidays for taiwan in 2040...
# Fetching holidays for thailand in 2021...
# Fetching holidays for thailand in 2022...
# Fetching holidays for thailand in 2023...
# Fetching holidays for thailand in 2024...
# Fetching holidays for thailand in 2025...
# Fetching holidays for thailand in 2026...
# Fetching holidays for thailand in 2027...
# Fetching holidays for thailand in 2028...
# Fetching holidays for thailand in 2029...
# Fetching holidays for thailand in 2030...
# Fetching holidays for thailand in 2031...
# Fetching holidays for thailand in 2032...
# Fetching holidays for thailand in 2033...
# Fetching holidays for thailand in 2034...
# Fetching holidays for thailand in 2035...
# Fetching holidays for thailand in 2036...
# Fetching holidays for thailand in 2037...
# Fetching holidays for thailand in 2038...
# Fetching holidays for thailand in 2039...
# Fetching holidays for thailand in 2040...
#            Date        Day                                           Name  \
# 0    1 Jan 2021     Friday                                 New Year's Day
# 1    2 Jan 2021   Saturday                                 Reconquest Day
# 2    6 Jan 2021  Wednesday                                       Epiphany
# 3   14 Feb 2021     Sunday                                Valentine's Day
# 4   15 Feb 2021     Monday                                Carnival Monday
# 5   16 Feb 2021    Tuesday                               Carnival Tuesday
# 6   17 Feb 2021  Wednesday                                  Ash Wednesday
# 7   28 Feb 2021     Sunday                               Day of Andalucía
# 8    1 Mar 2021     Monday                   Day off for Day of Andalucía
# 9    1 Mar 2021     Monday                    Day of the Balearic Islands
# 10  13 Mar 2021   Saturday  Statute of the Autonomous City of Melilla Day
# 11  19 Mar 2021     Friday                                   Fathers' Day
# 12  19 Mar 2021     Friday                                       San Jose
# 13  19 Mar 2021     Friday                                       San Jose
# 14  20 Mar 2021   Saturday                                  March Equinox
#
#                             Type Country
# 0               National Holiday   spain
# 1                     Observance   spain
# 2               National Holiday   spain
# 3                     Observance   spain
# 4                     Observance   spain
# 5                     Observance   spain
# 6                     Observance   spain
# 7   Autonomous Community Holiday   spain
# 8   Autonomous Community Holiday   spain
# 9   Autonomous Community Holiday   spain
# 10  Autonomous Community Holiday   spain
# 11                    Observance   spain
# 12                    Observance   spain
# 13  Autonomous Community Holiday   spain
# 14                        Season   spain

# %% [markdown]
# 'turkey',
# 'vietnam',
# 'ukraine',
# 'uk',
# 'new-zealand'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['turkey', 'vietnam', 'ukraine', 'uk', 'new-zealand']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_9.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for turkey in 2021...
# Fetching holidays for turkey in 2022...
# Fetching holidays for turkey in 2023...
# Fetching holidays for turkey in 2024...
# Fetching holidays for turkey in 2025...
# Fetching holidays for turkey in 2026...
# Fetching holidays for turkey in 2027...
# Fetching holidays for turkey in 2028...
# Fetching holidays for turkey in 2029...
# Fetching holidays for turkey in 2030...
# Fetching holidays for turkey in 2031...
# Fetching holidays for turkey in 2032...
# Fetching holidays for turkey in 2033...
# Fetching holidays for turkey in 2034...
# Fetching holidays for turkey in 2035...
# Fetching holidays for turkey in 2036...
# Fetching holidays for turkey in 2037...
# Fetching holidays for turkey in 2038...
# Fetching holidays for turkey in 2039...
# Fetching holidays for turkey in 2040...
# Fetching holidays for vietnam in 2021...
# Fetching holidays for vietnam in 2022...
# Fetching holidays for vietnam in 2023...
# Fetching holidays for vietnam in 2024...
# Fetching holidays for vietnam in 2025...
# Fetching holidays for vietnam in 2026...
# Fetching holidays for vietnam in 2027...
# Fetching holidays for vietnam in 2028...
# Fetching holidays for vietnam in 2029...
# Fetching holidays for vietnam in 2030...
# Fetching holidays for vietnam in 2031...
# Fetching holidays for vietnam in 2032...
# Fetching holidays for vietnam in 2033...
# Fetching holidays for vietnam in 2034...
# Fetching holidays for vietnam in 2035...
# Fetching holidays for vietnam in 2036...
# Fetching holidays for vietnam in 2037...
# Fetching holidays for vietnam in 2038...
# Fetching holidays for vietnam in 2039...
# Fetching holidays for vietnam in 2040...
# Fetching holidays for ukraine in 2021...
# Fetching holidays for ukraine in 2022...
# Fetching holidays for ukraine in 2023...
# Fetching holidays for ukraine in 2024...
# Fetching holidays for ukraine in 2025...
# Fetching holidays for ukraine in 2026...
# Fetching holidays for ukraine in 2027...
# Fetching holidays for ukraine in 2028...
# Fetching holidays for ukraine in 2029...
# Fetching holidays for ukraine in 2030...
# Fetching holidays for ukraine in 2031...
# Fetching holidays for ukraine in 2032...
# Fetching holidays for ukraine in 2033...
# Fetching holidays for ukraine in 2034...
# Fetching holidays for ukraine in 2035...
# Fetching holidays for ukraine in 2036...
# Fetching holidays for ukraine in 2037...
# Fetching holidays for ukraine in 2038...
# Fetching holidays for ukraine in 2039...
# Fetching holidays for ukraine in 2040...
# Fetching holidays for uk in 2021...
# Fetching holidays for uk in 2022...
# Fetching holidays for uk in 2023...
# Fetching holidays for uk in 2024...
# Fetching holidays for uk in 2025...
# Fetching holidays for uk in 2026...
# Fetching holidays for uk in 2027...
# Fetching holidays for uk in 2028...
# Fetching holidays for uk in 2029...
# Fetching holidays for uk in 2030...
# Fetching holidays for uk in 2031...
# Fetching holidays for uk in 2032...
# Fetching holidays for uk in 2033...
# Fetching holidays for uk in 2034...
# Fetching holidays for uk in 2035...
# Fetching holidays for uk in 2036...
# Fetching holidays for uk in 2037...
# Fetching holidays for uk in 2038...
# Fetching holidays for uk in 2039...
# Fetching holidays for uk in 2040...
# Fetching holidays for new-zealand in 2021...
# Fetching holidays for new-zealand in 2022...
# Fetching holidays for new-zealand in 2023...
# Fetching holidays for new-zealand in 2024...
# Fetching holidays for new-zealand in 2025...
# Fetching holidays for new-zealand in 2026...
# Fetching holidays for new-zealand in 2027...
# Fetching holidays for new-zealand in 2028...
# Fetching holidays for new-zealand in 2029...
# Fetching holidays for new-zealand in 2030...
# Fetching holidays for new-zealand in 2031...
# Fetching holidays for new-zealand in 2032...
# Fetching holidays for new-zealand in 2033...
# Fetching holidays for new-zealand in 2034...
# Fetching holidays for new-zealand in 2035...
# Fetching holidays for new-zealand in 2036...
# Fetching holidays for new-zealand in 2037...
# Fetching holidays for new-zealand in 2038...
# Fetching holidays for new-zealand in 2039...
# Fetching holidays for new-zealand in 2040...
#            Date        Day                                            Name  \
# 0    1 Jan 2021     Friday                                  New Year's Day
# 1   20 Mar 2021   Saturday                                   March Equinox
# 2   23 Apr 2021     Friday         National Sovereignty and Children's Day
# 3    1 May 2021   Saturday                        Labor and Solidarity Day
# 4   12 May 2021  Wednesday                               Ramadan Feast Eve
# 5   13 May 2021   Thursday                                   Ramadan Feast
# 6   14 May 2021     Friday                           Ramadan Feast Holiday
# 7   15 May 2021   Saturday                           Ramadan Feast Holiday
# 8   19 May 2021  Wednesday  Commemoration of Atatürk, Youth and Sports Day
# 9   21 Jun 2021     Monday                                   June Solstice
# 10  15 Jul 2021   Thursday                Democracy and National Unity Day
# 11  19 Jul 2021     Monday                             Sacrifice Feast Eve
# 12  20 Jul 2021    Tuesday                                     Eid al-Adha
# 13  21 Jul 2021  Wednesday                         Sacrifice Feast Holiday
# 14  22 Jul 2021   Thursday                         Sacrifice Feast Holiday
#
#                 Type Country
# 0   National Holiday  turkey
# 1             Season  turkey
# 2   National Holiday  turkey
# 3   National Holiday  turkey
# 4           Half Day  turkey
# 5   National Holiday  turkey
# 6   National Holiday  turkey
# 7   National Holiday  turkey
# 8   National Holiday  turkey
# 9             Season  turkey
# 10  National Holiday  turkey
# 11  National Holiday  turkey
# 12  National Holiday  turkey
# 13  National Holiday  turkey
# 14  National Holiday  turkey

# %% [markdown]
# 'belgium',
# 'luxembourg',
# 'chile',
# 'paraguay'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['belgium', 'luxembourg', 'chile', 'paraguay']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_10.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for belgium in 2021...
# Fetching holidays for belgium in 2022...
# Fetching holidays for belgium in 2023...
# Fetching holidays for belgium in 2024...
# Fetching holidays for belgium in 2025...
# Fetching holidays for belgium in 2026...
# Fetching holidays for belgium in 2027...
# Fetching holidays for belgium in 2028...
# Fetching holidays for belgium in 2029...
# Fetching holidays for belgium in 2030...
# Fetching holidays for belgium in 2031...
# Fetching holidays for belgium in 2032...
# Fetching holidays for belgium in 2033...
# Fetching holidays for belgium in 2034...
# Fetching holidays for belgium in 2035...
# Fetching holidays for belgium in 2036...
# Fetching holidays for belgium in 2037...
# Fetching holidays for belgium in 2038...
# Fetching holidays for belgium in 2039...
# Fetching holidays for belgium in 2040...
# Fetching holidays for luxembourg in 2021...
# Fetching holidays for luxembourg in 2022...
# Fetching holidays for luxembourg in 2023...
# Fetching holidays for luxembourg in 2024...
# Fetching holidays for luxembourg in 2025...
# Fetching holidays for luxembourg in 2026...
# Fetching holidays for luxembourg in 2027...
# Fetching holidays for luxembourg in 2028...
# Fetching holidays for luxembourg in 2029...
# Fetching holidays for luxembourg in 2030...
# Fetching holidays for luxembourg in 2031...
# Fetching holidays for luxembourg in 2032...
# Fetching holidays for luxembourg in 2033...
# Fetching holidays for luxembourg in 2034...
# Fetching holidays for luxembourg in 2035...
# Fetching holidays for luxembourg in 2036...
# Fetching holidays for luxembourg in 2037...
# Fetching holidays for luxembourg in 2038...
# Fetching holidays for luxembourg in 2039...
# Fetching holidays for luxembourg in 2040...
# Fetching holidays for chile in 2021...
# Fetching holidays for chile in 2022...
# Fetching holidays for chile in 2023...
# Fetching holidays for chile in 2024...
# Fetching holidays for chile in 2025...
# Fetching holidays for chile in 2026...
# Fetching holidays for chile in 2027...
# Fetching holidays for chile in 2028...
# Fetching holidays for chile in 2029...
# Fetching holidays for chile in 2030...
# Fetching holidays for chile in 2031...
# Fetching holidays for chile in 2032...
# Fetching holidays for chile in 2033...
# Fetching holidays for chile in 2034...
# Fetching holidays for chile in 2035...
# Fetching holidays for chile in 2036...
# Fetching holidays for chile in 2037...
# Fetching holidays for chile in 2038...
# Fetching holidays for chile in 2039...
# Fetching holidays for chile in 2040...
# Fetching holidays for paraguay in 2021...
# Fetching holidays for paraguay in 2022...
# Fetching holidays for paraguay in 2023...
# Fetching holidays for paraguay in 2024...
# Fetching holidays for paraguay in 2025...
# Fetching holidays for paraguay in 2026...
# Fetching holidays for paraguay in 2027...
# Fetching holidays for paraguay in 2028...
# Fetching holidays for paraguay in 2029...
# Fetching holidays for paraguay in 2030...
# Fetching holidays for paraguay in 2031...
# Fetching holidays for paraguay in 2032...
# Fetching holidays for paraguay in 2033...
# Fetching holidays for paraguay in 2034...
# Fetching holidays for paraguay in 2035...
# Fetching holidays for paraguay in 2036...
# Fetching holidays for paraguay in 2037...
# Fetching holidays for paraguay in 2038...
# Fetching holidays for paraguay in 2039...
# Fetching holidays for paraguay in 2040...
#            Date        Day                         Name  \
# 0    1 Jan 2021     Friday               New Year's Day
# 1    6 Jan 2021  Wednesday                     Epiphany
# 2   14 Feb 2021     Sunday              Valentine's Day
# 3   20 Mar 2021   Saturday                March Equinox
# 4   28 Mar 2021     Sunday  Daylight Saving Time starts
# 5    2 Apr 2021     Friday                  Good Friday
# 6    4 Apr 2021     Sunday                Easter Sunday
# 7    5 Apr 2021     Monday                Easter Monday
# 8    1 May 2021   Saturday          Labor Day / May Day
# 9    8 May 2021   Saturday                     Iris Day
# 10   9 May 2021     Sunday                 Mothers' Day
# 11  13 May 2021   Thursday                Ascension Day
# 12  14 May 2021     Friday      Day after Ascension Day
# 13  23 May 2021     Sunday                  Whit Sunday
# 14  24 May 2021     Monday                  Whit Monday
#
#                                  Type  Country
# 0                    National Holiday  belgium
# 1                          Observance  belgium
# 2                          Observance  belgium
# 3                              Season  belgium
# 4   Clock Change/Daylight Saving Time  belgium
# 5                        Bank holiday  belgium
# 6                          Observance  belgium
# 7                    National Holiday  belgium
# 8                    National Holiday  belgium
# 9         Regional government holiday  belgium
# 10                         Observance  belgium
# 11                   National Holiday  belgium
# 12                       Bank holiday  belgium
# 13                         Observance  belgium
# 14                   National Holiday  belgium

# %% [markdown]
# 'slovakia',
# 'ireland',
# 'iceland',
# 'us'

# %%
def fetch_holidays(country, year):
    # Fetches holiday data for a given country and year in desired format
    url = f"https://www.timeanddate.com/holidays/{country.lower()}/{year}?hl=en"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/',
        'DNT': '1',
        'Connection': 'keep-alive'
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"Failed to fetch {country} {year}: {response.status_code}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.text, 'html.parser')
        holiday_table = soup.find('table', {'id': 'holidays-table'})

        if not holiday_table:
            print(f"No holiday table found for {country} {year}")
            return pd.DataFrame()

        holidays = []

        for row in holiday_table.find_all('tr')[1:]:
            date_cell = row.find('th')
            cells = row.find_all('td')

            if date_cell and len(cells) >= 2:
                date_text = date_cell.get_text(strip=True)
                day_of_week = cells[0].get_text(strip=True)
                name = cells[1].get_text(strip=True)
                type_ = cells[2].get_text(strip=True) if len(cells) > 2 else ""

                if name:
                    holidays.append({
                        'Date': f"{date_text} {year}",
                        'Day': day_of_week,
                        'Name': name,
                        'Type': type_
                    })

        return pd.DataFrame(holidays)

    except requests.RequestException as e:
        print(f"Error fetching holidays for {country} {year}: {e}")
        return pd.DataFrame()

def scrape_holidays():
    # Scrapes and combines holidays for all selected countries.
    all_holidays = pd.DataFrame()
    country_codes = ['slovakia', 'ireland', 'iceland', 'us']

    for country in country_codes:
        for year in range(2021, 2041):
            print(f"Fetching holidays for {country} in {year}...")
            df = fetch_holidays(country, year)

            if not df.empty:
                df['Country'] = country
                df['Year'] = year    
                all_holidays = pd.concat([all_holidays, df], ignore_index=True)

            time.sleep(2)  # Delay between requests

    return all_holidays[['Date', 'Day', 'Name', 'Type', 'Country']]

# Run scraper and save output
if __name__ == "__main__":
    holiday_data = scrape_holidays()

    # Save to CSV
    holiday_data.to_csv("holidays_11.csv", index=False, encoding="utf-8-sig")

    # Display output
    print(holiday_data.head(15))
# Out:
# Fetching holidays for slovakia in 2021...
# Fetching holidays for slovakia in 2022...
# Fetching holidays for slovakia in 2023...
# Fetching holidays for slovakia in 2024...
# Fetching holidays for slovakia in 2025...
# Fetching holidays for slovakia in 2026...
# Fetching holidays for slovakia in 2027...
# Fetching holidays for slovakia in 2028...
# Fetching holidays for slovakia in 2029...
# Fetching holidays for slovakia in 2030...
# Fetching holidays for slovakia in 2031...
# Fetching holidays for slovakia in 2032...
# Fetching holidays for slovakia in 2033...
# Fetching holidays for slovakia in 2034...
# Fetching holidays for slovakia in 2035...
# Fetching holidays for slovakia in 2036...
# Fetching holidays for slovakia in 2037...
# Fetching holidays for slovakia in 2038...
# Fetching holidays for slovakia in 2039...
# Fetching holidays for slovakia in 2040...
# Fetching holidays for ireland in 2021...
# Fetching holidays for ireland in 2022...
# Fetching holidays for ireland in 2023...
# Fetching holidays for ireland in 2024...
# Fetching holidays for ireland in 2025...
# Fetching holidays for ireland in 2026...
# Fetching holidays for ireland in 2027...
# Fetching holidays for ireland in 2028...
# Fetching holidays for ireland in 2029...
# Fetching holidays for ireland in 2030...
# Fetching holidays for ireland in 2031...
# Fetching holidays for ireland in 2032...
# Fetching holidays for ireland in 2033...
# Fetching holidays for ireland in 2034...
# Fetching holidays for ireland in 2035...
# Fetching holidays for ireland in 2036...
# Fetching holidays for ireland in 2037...
# Fetching holidays for ireland in 2038...
# Fetching holidays for ireland in 2039...
# Fetching holidays for ireland in 2040...
# Fetching holidays for iceland in 2021...
# Fetching holidays for iceland in 2022...
# Fetching holidays for iceland in 2023...
# Fetching holidays for iceland in 2024...
# Fetching holidays for iceland in 2025...
# Fetching holidays for iceland in 2026...
# Fetching holidays for iceland in 2027...
# Fetching holidays for iceland in 2028...
# Fetching holidays for iceland in 2029...
# Fetching holidays for iceland in 2030...
# Fetching holidays for iceland in 2031...
# Fetching holidays for iceland in 2032...
# Fetching holidays for iceland in 2033...
# Fetching holidays for iceland in 2034...
# Fetching holidays for iceland in 2035...
# Fetching holidays for iceland in 2036...
# Fetching holidays for iceland in 2037...
# Fetching holidays for iceland in 2038...
# Fetching holidays for iceland in 2039...
# Fetching holidays for iceland in 2040...
# Fetching holidays for us in 2021...
# Fetching holidays for us in 2022...
# Fetching holidays for us in 2023...
# Fetching holidays for us in 2024...
# Fetching holidays for us in 2025...
# Fetching holidays for us in 2026...
# Fetching holidays for us in 2027...
# Fetching holidays for us in 2028...
# Fetching holidays for us in 2029...
# Fetching holidays for us in 2030...
# Fetching holidays for us in 2031...
# Fetching holidays for us in 2032...
# Fetching holidays for us in 2033...
# Fetching holidays for us in 2034...
# Fetching holidays for us in 2035...
# Fetching holidays for us in 2036...
# Fetching holidays for us in 2037...
# Fetching holidays for us in 2038...
# Fetching holidays for us in 2039...
# Fetching holidays for us in 2040...
#            Date        Day                                               Name  \
# 0    1 Jan 2021     Friday                                       Republic Day
# 1    6 Jan 2021  Wednesday                                           Epiphany
# 2   20 Mar 2021   Saturday                                      March Equinox
# 3   25 Mar 2021   Thursday                      Struggle for Human Rights Day
# 4    2 Apr 2021     Friday                                        Good Friday
# 5    4 Apr 2021     Sunday                                      Easter Sunday
# 6    5 Apr 2021     Monday                                      Easter Monday
# 7   13 Apr 2021    Tuesday                    Unfairly Prosecuted Persons Day
# 8    1 May 2021   Saturday                                          Labor Day
# 9    1 May 2021   Saturday                Accession to the European Union Day
# 10   4 May 2021    Tuesday                Death Anniversary of M. R. Štefánik
# 11   8 May 2021   Saturday                        Day of Victory Over Fascism
# 12   9 May 2021     Sunday                                       Mothers' Day
# 13   7 Jun 2021     Monday  Anniversary of the Memorandum of the Slovak Na...
# 14  20 Jun 2021     Sunday                                       Fathers' Day
#
#                      Type   Country
# 0        National Holiday  slovakia
# 1        National Holiday  slovakia
# 2                  Season  slovakia
# 3              Observance  slovakia
# 4        National Holiday  slovakia
# 5   Observance, Christian  slovakia
# 6        National Holiday  slovakia
# 7              Observance  slovakia
# 8        National Holiday  slovakia
# 9              Observance  slovakia
# 10             Observance  slovakia
# 11       National Holiday  slovakia
# 12             Observance  slovakia
# 13             Observance  slovakia
# 14             Observance  slovakia

# %% [markdown]
# ### Consolidated File

# %%
# Get all matching CSV files
csv_files = glob.glob("holidays_*.csv")

# Check if any files are found
if not csv_files:
    print("No matching CSV files found.")
else:
    # Print all CSV files that will be merged
    print("Merging the following CSV files:")
    for file in csv_files:
        print(file)

    # Read all CSV files using utf-8-sig encoding
    df_list = [pd.read_csv(file, encoding="utf-8-sig") for file in csv_files]

    # Concatenate them into a single DataFrame
    df = pd.concat(df_list, ignore_index=True)

    # Save the merged DataFrame using utf-8-sig encoding
    output_file = "holidays_2021_2040.csv"
    df.to_csv(output_file, index=False, encoding="utf-8-sig")

    # Display the first few rows
    print(df.head())

    print(f"CSV files merged successfully! The consolidated file is saved as '{output_file}'.")
# Out:
# Merging the following CSV files:
# holidays_1.csv
# holidays_10.csv
# holidays_11.csv
# holidays_2.csv
# holidays_3.csv
# holidays_4.csv
# holidays_5.csv
# holidays_6.csv
# holidays_7.csv
# holidays_8.csv
# holidays_9.csv
#           Date        Day                    Name              Type    Country
# 0   1 Jan 2021     Friday          New Year's Day  National Holiday  australia
# 1   6 Jan 2021  Wednesday                Epiphany         Christian  australia
# 2   7 Jan 2021   Thursday  Orthodox Christmas Day          Orthodox  australia
# 3  14 Jan 2021   Thursday       Orthodox New Year          Orthodox  australia
# 4  26 Jan 2021    Tuesday           Australia Day  National Holiday  australia
# CSV files merged successfully! The consolidated file is saved as 'holidays_2021_2040.csv'.
